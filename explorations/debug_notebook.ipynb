# %%
# %sql

select * from goodcabs.realtime.bronze_streaming_ride_events;

# %%
# %sql

select * from goodcabs.realtime.silver_streaming_ride_events;

# %%
# %sql

select * from goodcabs.realtime.gold_cancellations

# %%
# %sql

select * from goodcabs.realtime.gold_live_kpis

# %%
# %sql

select * from goodcabs.realtime.gold_pickup_demand

# %%
# %sql

select * from goodcabs.realtime.gold_revenue_per_minute

# %%
# %sql

select * from goodcabs.realtime.gold_ride_status_breakdown

# %%
# %sql

select * from goodcabs.realtime.gold_rides_by_city

# %%
# %sql

select * from goodcabs.realtime.gold_top_zones
